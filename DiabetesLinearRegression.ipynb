# %%
import pandas as pd

data=pd.read_csv('diabetes.csv')
data.head()
# Out:
#    age  sex   bmi     bp   tc    ldl   hdl  tch     ltg  glu  \
# 0   59    2  32.1  101.0  157   93.2  38.0  4.0  4.8598   87
# 1   48    1  21.6   87.0  183  103.2  70.0  3.0  3.8918   69
# 2   72    2  30.5   93.0  156   93.6  41.0  4.0  4.6728   85
# 3   24    1  25.3   84.0  198  131.4  40.0  5.0  4.8903   89
# 4   50    1  23.0  101.0  192  125.4  52.0  4.0  4.2905   80
#
#    response_interest
# 0                151
# 1                 75
# 2                141
# 3                206
# 4                135

# %%
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

x = data.copy()
x=x.pop('bmi')
y=data.copy()
y=y.pop('response_interest')

fig,ax=plt.subplots()
ax.scatter(x,y, label="Data points", color='red',marker='*',linewidth=1.75)
ax.set_xlabel("X- bmi",fontsize=12)
ax.set_ylabel("Y- interest", fontsize=12)
ax.legend()
plt.show()

lr_model = LinearRegression().fit(x_new,y)

# %%
x_new = x.values
x_new = x_new.reshape(-1,1)
lr_model = LinearRegression().fit(x_new,y)
y_pred = lr_model.predict(x_new)

fig,ax = plt.subplots()
ax.scatter(x_new,y,label="Data points",color='blue')
ax.set_xlabel("X- bmi")
ax.set_ylabel("Y- interest")


ax.plot(x_new,y_pred,label='Linear Regression', color='orange')
ax.legend()
plt.show()

# %%
w=lr_model.coef_[0]
b=lr_model.intercept_
print("f(x) = {:.4f}x + {:.4f} ".format(w,b))
# Out:
# y_hat = f(x) = 10.2331x + -117.7734

# %%
from sklearn.metrics import mean_squared_error , mean_absolute_error ,r2_score

mse=mean_squared_error(y,y_pred)
mae=mean_absolute_error(y,y_pred)
r2score=r2_score(y,y_pred)
print("MSE is ",mse)
print("MAE is ",mae)
print("r2_score is ",r2score)
# Out:
# MSE is  3890.4565854612724
# MAE is  51.798627639533656
# r2_score is  0.3439237602253803
